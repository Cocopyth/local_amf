# %%
# %matplotlib widget

import handcalcs.render
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from math import pi
import forallpeople as si
import matplotlib as mpl

si.environment('custom')

# %%
# %%render
# tot_length = 3*si.m
# r = 2 *si.m*1e-6
#
# tot_volume = pi*r**2*tot_length
# density = 1 *1e3 *si.kg*si.m**(-3)
# tot_wet_mass = tot_volume*density
# dry_ratio = 0.3
# tot_dw = dry_ratio * tot_wet_mass
# Out:
# \[
# \begin{aligned}
# \mathrm{tot}_{length} &= 3 \cdot \mathrm{si.m}  = 3 \cdot si.m &= 3.000\ \mathrm{m}
# \\[10pt]
# r &= 2 \cdot \mathrm{si.m} \cdot 1 \times 10 ^ {-6}  = 2 \cdot si.m \cdot 1 \times 10 ^ {-6} &= 2.000\ \mathrm{μm}
# \\[10pt]
# \mathrm{tot}_{volume} &= \pi \cdot \left( r \right) ^{ 2 } \cdot \mathrm{tot}_{length}  = 3.142 \cdot \left( 2.000\ \mathrm{μm} \right) ^{ 2 } \cdot 3.000\ \mathrm{m} &= 37699111.843\ \mathrm{μm}^{3}
# \\[10pt]
# \mathrm{density} &= 1 \cdot 1 \times 10 ^ {3} \cdot \mathrm{si.kg} \cdot \left( \mathrm{si.m} \right) ^{ \left( - 3 \right) } \\&= 1 \cdot 1 \times 10 ^ {3} \cdot si.kg \cdot \left( si.m \right) ^{ \left( - 3 \right) } \\&= 1000.000\ \mathrm{kg} \cdot \mathrm{m}^{-3}  \\[10pt]
# \\[10pt]
# \mathrm{tot}_{wet_{mass}} &= \mathrm{tot}_{volume} \cdot \mathrm{density}  = 37699111.843\ \mathrm{μm}^{3} \cdot 1000.000\ \mathrm{kg} \cdot \mathrm{m}^{-3} &= 37.699\ \mathrm{μg}
# \\[10pt]
# \mathrm{dry}_{ratio} &= 0.300 \;
# \\[10pt]
# \mathrm{tot}_{dw} &= \mathrm{dry}_{ratio} \cdot \mathrm{tot}_{wet_{mass}}  = 0.300 \cdot 37.699\ \mathrm{μg} &= 11.310\ \mathrm{μg}
# \end{aligned}
# \]

# %%
tot_dw*(si.m*1e-2)**2
# Out:
# 235.619 ng

# %%
datatable = pd.read_csv('Fungal_trait_data.csv')

# %%
fig,ax = plt.subplots()
ax.boxplot(datatable['density'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24eb0fb80a0>,
#   <matplotlib.lines.Line2D at 0x24eb0fb8340>],
#  'caps': [<matplotlib.lines.Line2D at 0x24eb0fb84c0>,
#   <matplotlib.lines.Line2D at 0x24eb0fb8760>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24eb0377e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x24eb0fb8a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24eb0fb8ca0>],
#  'means': []}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
