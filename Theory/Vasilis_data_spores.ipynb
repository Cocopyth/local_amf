# %%
# %matplotlib widget
import pandas as pd
data = pd.read_excel("vasilis_data.xlsx",sheet_name="Experiment_2")
data['speed (um.h-1)'] = data['HSPEED']/24
data['density (pixel.cm-2)'] = data['ND']/(1.5**2)

# %%
data = data.loc[data['HOST']=='Carrot']

# %%
data
# Out:
#      REP  STRAIN  KAR    HOST  DERM        HSPEED  TSPOR  SPORES  \
# 0      1      A5  Dik  Carrot    42   7500.000000     12    6412
# 1      2      A5  Dik  Carrot    13   7500.000000     27    5251
# 2      3      A5  Dik  Carrot     9   7500.000000     34    4873
# 3      4      A5  Dik  Carrot    17   7500.000000     25    5986
# 4      5      A5  Dik  Carrot    17   7500.000000     27    5487
# 5      6      A5  Dik  Carrot    21   7500.000000     31    4786
# 16     1      A4  Dik  Carrot    16   4285.714286     52    1810
# 17     2      A4  Dik  Carrot    18   6000.000000     46    4005
# 18     3      A4  Dik  Carrot    23   7500.000000     26    3899
# 19     4      A4  Dik  Carrot    45  10000.000000     19    6577
# 20     5      A4  Dik  Carrot    45   7500.000000     34    5960
# 28     2     SL1  Dik  Carrot    14   7500.000000     47     111
# 29     3     SL1  Dik  Carrot    14   6000.000000     60   10154
# 30     4     SL1  Dik  Carrot    14   7500.000000     28    6810
# 31     5     SL1  Dik  Carrot    35   6000.000000     37   10441
# 32     7     SL1  Dik  Carrot    22   7500.000000     27     984
# 33     6     SL1  Dik  Carrot    15  10000.000000     41    9544
# 43     1      G1  Dik  Carrot    14  15000.000000     57    7451
# 44     2      G1  Dik  Carrot    14   6000.000000     37   12744
# 45     3      G1  Dik  Carrot    14   6000.000000     49   10079
# 46     4      G1  Dik  Carrot    14  15000.000000     42   10244
# 47     5      G1  Dik  Carrot    14  15000.000000     53    1044
# 48     6      G1  Dik  Carrot    14   7500.000000     21    9368
# 49     8      G1  Dik  Carrot    24  10000.000000      7    6987
# 59     1     330  Hom  Carrot     4   7500.000000     51    4871
# 60     2     330  Hom  Carrot    11   4285.714286     67     764
# 61     3     330  Hom  Carrot    35   5000.000000     32     617
# 62     4     330  Hom  Carrot    27   5000.000000     18     501
# 63     5     330  Hom  Carrot    37   6000.000000     28      89
# 64     6     330  Hom  Carrot     7   7500.000000     42     467
# 73     1      66  Hom  Carrot    24   6000.000000     28    3744
# 74     2      66  Hom  Carrot    24   5000.000000     24    4960
# 75     3      66  Hom  Carrot     8   3750.000000     54    2130
# 76     4      66  Hom  Carrot    11   5000.000000     50     698
# 77     5      66  Hom  Carrot    25   4285.714286     32    4187
# 87     2  197198  Hom  Carrot    14   7500.000000     49    9523
# 88     3  197198  Hom  Carrot    16   7500.000000     58    5698
# 89     4  197198  Hom  Carrot    16   7500.000000     57    6939
# 90     5  197198  Hom  Carrot    28  10000.000000     22    1589
# 98     1     101  Hom  Carrot    14   7500.000000     60     899
# 99     2     101  Hom  Carrot    23   4285.714286     29    5261
# 100    3     101  Hom  Carrot    50   5000.000000     24    2145
# 101    4     101  Hom  Carrot    50   3750.000000     23     544
# 102    6     101  Hom  Carrot    34   4285.714286     18     985
#
#                HL     BF     ND
# 0    1.257041e+07  0.113  34923
# 1    1.368254e+07  0.135  44074
# 2    1.089962e+07  0.122  43776
# 3    1.131000e+07  0.126  44504
# 4    1.274170e+07  0.137  38779
# 5    9.856333e+06  0.114  35845
# 16   1.232100e+07  0.147  43284
# 17   1.684460e+07  0.166  47382
# 18   1.411000e+07  0.156  47084
# 19   1.469837e+07  0.142  37816
# 20   1.203321e+07  0.147  38390
# 28   9.605400e+06  0.158  52046
# 29   1.266630e+07  0.177  57070
# 30   1.204000e+07  0.157  45186
# 31   1.378400e+07  0.153  45684
# 32   1.123600e+07  0.163  51201
# 33   1.074500e+07  0.159  52633
# 43   9.541000e+06  0.137  38437
# 44   1.452000e+07  0.150  40902
# 45   1.262000e+07  0.137  38322
# 46   1.142300e+07  0.148  39676
# 47   6.512000e+06  0.113  20654
# 48   1.095500e+07  0.138  39571
# 49   7.658000e+06  0.116  29574
# 59   9.451300e+06  0.094  35145
# 60   4.979015e+06  0.051  18454
# 61   5.479612e+06  0.061  23686
# 62   4.032695e+06  0.048  15569
# 63   1.457963e+06  0.045  16896
# 64   1.756174e+06  0.050  17568
# 73   9.570464e+06  0.120  35446
# 74   1.203321e+07  0.129  38244
# 75   7.694233e+06  0.126  39948
# 76   1.024155e+06  0.120  35586
# 77   8.465311e+06  0.128  30544
# 87   7.895622e+06  0.104  28343
# 88   5.211301e+06  0.093  29333
# 89   6.083880e+06  0.092  29991
# 90   4.965233e+06  0.107  30012
# 98   9.853142e+06  0.098  25493
# 99   1.023000e+07  0.129  32980
# 100  1.023921e+07  0.122  31464
# 101  9.963500e+06  0.108  27388
# 102  1.040500e+07  0.301  33302

# %%
data.plot('speed (um.h-1)','density (pixel.cm-2)',kind="scatter")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:xlabel='speed (um.h-1)', ylabel='density (pixel.cm-2)'>

# %%
from scipy.stats import pearsonr
import numpy as np
corr = data.corr()
pval = data.corr(method=lambda x, y: pearsonr(x, y)[1]) - np.eye(*corr.shape)
p = pval.applymap(lambda x: ''.join(['*' for t in [0.01,0.05,0.1] if x<=t]))
# corr.style.background_gradient(cmap='coolwarm')
corr[.round(2).astype(str) + p
# Out:
#             REP      DERM   HSPEED     TSPOR   SPORES       HL       BF  \
# REP      1.0***   0.32***     0.13    -0.16*     0.08     0.06    0.17*
# DERM    0.32***    1.0***    -0.06  -0.39***   -0.18*    -0.12    -0.13
# HSPEED     0.13     -0.06   1.0***   0.53***  0.52***  0.57***  0.62***
# TSPOR    -0.16*  -0.39***  0.53***    1.0***  0.32***  0.37***  0.42***
# SPORES     0.08    -0.18*  0.52***   0.32***   1.0***  0.78***  0.68***
# HL         0.06     -0.12  0.57***   0.37***  0.78***   1.0***   0.9***
# BF        0.17*     -0.13  0.62***   0.42***  0.68***   0.9***   1.0***
# ND         0.14     -0.14  0.67***   0.49***  0.73***  0.91***  0.93***
#
#              ND
# REP        0.14
# DERM      -0.14
# HSPEED  0.67***
# TSPOR   0.49***
# SPORES  0.73***
# HL      0.91***
# BF      0.93***
# ND       1.0***

# %%
data
# Out:
#      REP  STRAIN  KAR    HOST  DERM        HSPEED  TSPOR  SPORES  \
# 0      1      A5  Dik  Carrot    42   7500.000000     12    6412
# 1      2      A5  Dik  Carrot    13   7500.000000     27    5251
# 2      3      A5  Dik  Carrot     9   7500.000000     34    4873
# 3      4      A5  Dik  Carrot    17   7500.000000     25    5986
# 4      5      A5  Dik  Carrot    17   7500.000000     27    5487
# 5      6      A5  Dik  Carrot    21   7500.000000     31    4786
# 16     1      A4  Dik  Carrot    16   4285.714286     52    1810
# 17     2      A4  Dik  Carrot    18   6000.000000     46    4005
# 18     3      A4  Dik  Carrot    23   7500.000000     26    3899
# 19     4      A4  Dik  Carrot    45  10000.000000     19    6577
# 20     5      A4  Dik  Carrot    45   7500.000000     34    5960
# 28     2     SL1  Dik  Carrot    14   7500.000000     47     111
# 29     3     SL1  Dik  Carrot    14   6000.000000     60   10154
# 30     4     SL1  Dik  Carrot    14   7500.000000     28    6810
# 31     5     SL1  Dik  Carrot    35   6000.000000     37   10441
# 32     7     SL1  Dik  Carrot    22   7500.000000     27     984
# 33     6     SL1  Dik  Carrot    15  10000.000000     41    9544
# 43     1      G1  Dik  Carrot    14  15000.000000     57    7451
# 44     2      G1  Dik  Carrot    14   6000.000000     37   12744
# 45     3      G1  Dik  Carrot    14   6000.000000     49   10079
# 46     4      G1  Dik  Carrot    14  15000.000000     42   10244
# 47     5      G1  Dik  Carrot    14  15000.000000     53    1044
# 48     6      G1  Dik  Carrot    14   7500.000000     21    9368
# 49     8      G1  Dik  Carrot    24  10000.000000      7    6987
# 59     1     330  Hom  Carrot     4   7500.000000     51    4871
# 60     2     330  Hom  Carrot    11   4285.714286     67     764
# 61     3     330  Hom  Carrot    35   5000.000000     32     617
# 62     4     330  Hom  Carrot    27   5000.000000     18     501
# 63     5     330  Hom  Carrot    37   6000.000000     28      89
# 64     6     330  Hom  Carrot     7   7500.000000     42     467
# 73     1      66  Hom  Carrot    24   6000.000000     28    3744
# 74     2      66  Hom  Carrot    24   5000.000000     24    4960
# 75     3      66  Hom  Carrot     8   3750.000000     54    2130
# 76     4      66  Hom  Carrot    11   5000.000000     50     698
# 77     5      66  Hom  Carrot    25   4285.714286     32    4187
# 87     2  197198  Hom  Carrot    14   7500.000000     49    9523
# 88     3  197198  Hom  Carrot    16   7500.000000     58    5698
# 89     4  197198  Hom  Carrot    16   7500.000000     57    6939
# 90     5  197198  Hom  Carrot    28  10000.000000     22    1589
# 98     1     101  Hom  Carrot    14   7500.000000     60     899
# 99     2     101  Hom  Carrot    23   4285.714286     29    5261
# 100    3     101  Hom  Carrot    50   5000.000000     24    2145
# 101    4     101  Hom  Carrot    50   3750.000000     23     544
# 102    6     101  Hom  Carrot    34   4285.714286     18     985
#
#                HL     BF     ND
# 0    1.257041e+07  0.113  34923
# 1    1.368254e+07  0.135  44074
# 2    1.089962e+07  0.122  43776
# 3    1.131000e+07  0.126  44504
# 4    1.274170e+07  0.137  38779
# 5    9.856333e+06  0.114  35845
# 16   1.232100e+07  0.147  43284
# 17   1.684460e+07  0.166  47382
# 18   1.411000e+07  0.156  47084
# 19   1.469837e+07  0.142  37816
# 20   1.203321e+07  0.147  38390
# 28   9.605400e+06  0.158  52046
# 29   1.266630e+07  0.177  57070
# 30   1.204000e+07  0.157  45186
# 31   1.378400e+07  0.153  45684
# 32   1.123600e+07  0.163  51201
# 33   1.074500e+07  0.159  52633
# 43   9.541000e+06  0.137  38437
# 44   1.452000e+07  0.150  40902
# 45   1.262000e+07  0.137  38322
# 46   1.142300e+07  0.148  39676
# 47   6.512000e+06  0.113  20654
# 48   1.095500e+07  0.138  39571
# 49   7.658000e+06  0.116  29574
# 59   9.451300e+06  0.094  35145
# 60   4.979015e+06  0.051  18454
# 61   5.479612e+06  0.061  23686
# 62   4.032695e+06  0.048  15569
# 63   1.457963e+06  0.045  16896
# 64   1.756174e+06  0.050  17568
# 73   9.570464e+06  0.120  35446
# 74   1.203321e+07  0.129  38244
# 75   7.694233e+06  0.126  39948
# 76   1.024155e+06  0.120  35586
# 77   8.465311e+06  0.128  30544
# 87   7.895622e+06  0.104  28343
# 88   5.211301e+06  0.093  29333
# 89   6.083880e+06  0.092  29991
# 90   4.965233e+06  0.107  30012
# 98   9.853142e+06  0.098  25493
# 99   1.023000e+07  0.129  32980
# 100  1.023921e+07  0.122  31464
# 101  9.963500e+06  0.108  27388
# 102  1.040500e+07  0.301  33302

# %%
data.boxplot('speed (um.h-1)',by="STRAIN")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:title={'center':'speed (um.h-1)'}, xlabel='STRAIN'>

# %%
data.boxplot('density (pixel.cm-2)',by="STRAIN")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:title={'center':'density (pixel.cm-2)'}, xlabel='STRAIN'>

# %%
fs[1](0)
# Out:
# 1

# %%
data.groupby('STRAIN').mean().boxplot('HSPEED')
# Out:
# <AxesSubplot:>
