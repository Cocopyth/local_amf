# %%
import pandas as pd
import matplotlib.pyplot as plt
data2 = pd.read_csv('TemperatureHumidityPRINCE_20201219_1310.txt',sep = ';')
# data2 = pd.read_csv('TemperatureHumidityPRINCE_20210115_1210.txt',sep = ';',header= None,names = list(data2.columns))
# data2 = pd.read_csv('TemperatureHumidityPRINCE_20210217_0810Last.txt',sep = ';',header= None,names = list(data2.columns))
# data2 = pd.read_csv('TemperatureHumidityPRINCE_20210112_2010.txt',sep = ';',header= None,names = list(data2.columns))

# %%
data/TemperatureHumidityPRINCE_20210112_2010.txt
# Out:
#     Ts01   Ts02   Ts03   Ts04   Ts05   Ts06   Ts07   Ts08   Ts09   Ts10  ...  \
# 0   23.5   23.2   23.2   24.0   23.5   23.9   23.4   23.0   23.3   23.1  ...
# 1   23.5   23.2   23.2   23.9   23.5   23.9   23.4   23.0   23.3   23.2  ...
# 2   23.5   23.2   23.2   24.0   23.5   23.9   23.5   23.0   23.3   23.1  ...
# 3   23.5   23.2   23.2   24.0   23.5   23.9   23.4   22.9   23.3   23.1  ...
# 4   23.4   23.2   23.2   23.9   23.5   23.9   23.4   22.9   23.3   23.1  ...
# 5   23.5   23.2   23.2   24.0   23.5   23.9   23.4   23.0   23.3   23.2  ...
# 6   23.5   23.2   23.2   24.0   23.5   23.9   23.4   23.0   23.3   23.1  ...
# 7   23.5   23.2   23.2   24.0   23.5   23.9   23.4   23.0   23.3   23.2  ...
# 8   23.5   23.2   23.2   24.0   23.5   23.9   23.4   23.0   23.4   23.1  ...
# 9   23.5   23.2   23.2   24.0   23.5   23.9   23.5   23.0   23.4   23.1  ...
# 10  23.5   23.2   23.2   24.1   23.5   23.9   23.5   23.0   23.4   23.2  ...
# ...

# %%
fig = plt.figure()
ax = plt.subplot(111)
for y in data2.columns[3:4]:
    ax.plot(data2[' hours'],data2[y])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
fig = plt.figure()
ax = plt.subplot(111)
kind = "line"
data2.plot(' hours','Ts01',kind=kind,ax=ax)
data2.plot(' hours',' Ts04',kind=kind,ax=ax,color='red')
data2.plot(' hours',' Ts15',kind=kind,ax=ax,color='green')
ax.set_ylabel('temp (°C)')
ax.set_xlabel('time (h)')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Text(0.5, 0, 'time (h)')

# %%
data2.columns
# Out:
# Index(['Ts01', ' Ts02', ' Ts03', ' Ts04', ' Ts05', ' Ts06', ' Ts07', ' Ts08',
#        ' Ts09', ' Ts10', ' Ts11', ' Ts12', ' Ts13', ' Ts14', ' Ts15', ' Ts01',
#        ' Hs02', ' Hs03', ' Hs04', ' Hs05', ' Hs06', ' Hs07', ' Hs08', ' Hs09',
#        ' Hs10', ' Hs11', ' Hs12', ' Hs13', ' Hs14', ' Hs15', ' hours'],
#       dtype='object')
