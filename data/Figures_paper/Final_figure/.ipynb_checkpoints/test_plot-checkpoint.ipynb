# %%
import os
import matplotlib.pyplot as plt
import os
import pandas as pd
from amftrack.util.sys import get_analysis_folders,get_time_plate_info_from_analysis,get_time_hypha_info_from_analysis,get_global_hypha_info_from_analysis 
import numpy as np
import imageio
import os
import cv2
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from amftrack.pipeline.final_analysis.density_wave import get_wave_fit, S, dS, wave, dwave
import matplotlib.patches as mpatches
from random import choice
import statsmodels.api as sm
import scipy
import matplotlib as mpl
from amftrack.util.plot import gridplot
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns

# %matplotlib widget
plt.style.use('presentation.mplstyle')
# Out:
# c:\users\coren\documents\phd\code\amftrack\amftrack\util\dbx.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from matplotlib import font_manager
fontpaths = r'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\'
fonts = font_manager.findSystemFonts(fontpaths=fontpaths, fontext="ttf")
fonts.sort()
# fonts

# %%
fonts
# Out:
# ['C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-Bold.ttf',
#  'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-BoldOblique.ttf',
#  'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans-Oblique.ttf',
#  'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf',
#  'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansDisplay.ttf',
#  'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-Bold.ttf',
#  'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSansMono-BoldOblique.ttf',
# ...

# %%
font_manager.findfont("DejaVuSans") # Test with "Special Elite" too
# Out:
# 'C:\\Users\\coren\\anaconda3\\envs\\amftrack\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'

# %%
# Create a random pandas DataFrame
np.random.seed(42)  # Set random seed for reproducibility
data = np.random.rand(10, 2)  # Generate random data
df = pd.DataFrame(data, columns=['A', 'B'])  # Create DataFrame with columns 'A' and 'B'

# Plot DataFrame
df.plot()
plt.xlabel('rhinoceros')  # Set x-axis label
plt.ylabel('Values')  # Set y-axis label
plt.title('Random DataFrame')  # Set plot title
plt.show()
# Out:
# 2023-04-11 16:29:35,589-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# 2023-04-11 16:29:35,597-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# 2023-04-11 16:29:35,608-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# 2023-04-11 16:29:35,617-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# 2023-04-11 16:29:35,627-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# 2023-04-11 16:29:35,635-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# 2023-04-11 16:29:35,644-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# 2023-04-11 16:29:35,655-[WARNING]- matplotlib.font_manager:1424 -> findfont: Font family "'Helvetica'" not found.
# ...

# %%
import matplotlib.font_manager as fm

# List all available fonts
all_fonts = fm.findSystemFonts()
for font in all_fonts:
    print(font)
# Out:
# C:\Windows\Fonts\PERB____.TTF
# C:\Windows\Fonts\VLADIMIR.TTF
# C:\Windows\Fonts\msyh.ttc
# C:\Windows\Fonts\INFROMAN.TTF
# C:\Windows\Fonts\BOD_CR.TTF
# C:\Windows\Fonts\ERASBD.TTF
# C:\Windows\Fonts\BOD_CI.TTF
# C:\Windows\Fonts\BELL.TTF
# C:\Windows\Fonts\GARABD.TTF
# C:\Windows\Fonts\SCHLBKB.TTF
# C:\Windows\Fonts\GARAIT.TTF
# C:\Windows\Fonts\MAIAN.TTF
# C:\Windows\Fonts\VIVALDII.TTF
# C:\Windows\Fonts\MISTRAL.TTF
# C:\Windows\Fonts\CENTAUR.TTF
# C:\Windows\Fonts\YuGothR.ttc
# C:\Windows\Fonts\consolab.ttf
# C:\Windows\Fonts\SitkaI.ttc
# C:\Windows\Fonts\FTLTLT.TTF
# C:\Windows\Fonts\GILSANUB.TTF
# C:\Windows\Fonts\Sitka.ttc
# C:\Windows\Fonts\cambria.ttc
# C:\Windows\Fonts\seguisb.ttf
# C:\Windows\Fonts\ROCK.TTF
# C:\Windows\Fonts\seguisbi.ttf
# C:\Windows\Fonts\taile.ttf
# C:\Windows\Fonts\gadugi.ttf
# C:\Windows\Fonts\PERBI___.TTF
# C:\Windows\Fonts\framdit.ttf
# C:\Windows\Fonts\segoesc.ttf
# C:\Windows\Fonts\PERI____.TTF
# C:\Windows\Fonts\himalaya.ttf
# ...
