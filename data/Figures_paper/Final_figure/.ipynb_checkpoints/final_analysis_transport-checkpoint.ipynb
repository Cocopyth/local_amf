# %%
# %matplotlib widget

import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path_root = r"C:\Users\coren\Documents\PhD\temp\datatables"

# %%
paths = [path for path in os.listdir(path_root) if path.split('.')[-1]=='csv']
paths
# Out:
# ['201209_Plate40.csv',
#  '201210_Plate39.csv',
#  '201210_Plate40.csv',
#  '201217_Plate10.csv',
#  '201217_Plate38.csv',
#  '211012_Plate799.csv']

# %%
table = pd.DataFrame()
for path in paths:
    table = pd.concat([table,pd.read_csv(os.path.join(path_root,path))])

# %%
table
# Out:
#     Unnamed: 0  kymo_id  video_id  posx  posy   speed+    speed-  \
# 0            0        1         1  4851   566   7.0437  -14.6430
# 1            1        2         1  4851   566  24.0480  -46.8660
# 2            2        3         1  4851   566  11.5420 -113.8200
# 3            3        4         2  4750   872  17.2230  -46.4940
# 4            4        5         2  4750   872  19.5500  -19.7400
# ..         ...      ...       ...   ...   ...      ...       ...
# 25          25       27        16  3315  4000   8.2526   -7.3031
# 26          26       28        16  3315  4000   9.4028   -5.4898
# 27          27       29        17  3782  3779   8.2378  -12.0370
# 28          28       30        18  4388  3504   6.6123   -8.3259
# 29          29       31        19  5088  3302   3.1267   -1.5559
#
#     spore_density_2000  spore_density_1000  spore_density_500  \
# 0             0.003094            0.001728                0.0
# 1             0.003094            0.001728                0.0
# 2             0.003094            0.001728                0.0
# 3             0.002210            0.000000                0.0
# 4             0.002210            0.000000                0.0
# ..                 ...                 ...                ...
# 25            0.001710            0.000000                0.0
# 26            0.001710            0.000000                0.0
# 27            0.002396            0.000000                0.0
# 28            0.000686            0.000000                0.0
# 29            0.000000            0.000000                0.0
#
#     spore_density_num_2000  spore_density_num_1000  spore_density_num_500  \
# 0                        2                       1                      0
# 1                        2                       1                      0
# 2                        2                       1                      0
# 3                        3                       0                      0
# 4                        3                       0                      0
# ..                     ...                     ...                    ...
# 25                       2                       0                      0
# 26                       2                       0                      0
# 27                       3                       0                      0
# 28                       1                       0                      0
# 29                       0                       0                      0
#
#     time_since_crossing  tot_num_spore
# 0                   NaN            380
# 1                   NaN            380
# 2                   NaN            380
# 3                   NaN            380
# 4                   NaN            380
# ..                  ...            ...
# 25                  NaN             72
# 26                  NaN             72
# 27                  NaN             72
# 28                  NaN             72
# 29                  NaN             72
#
# [260 rows x 15 columns]

# %%
fig,ax = plt.subplots()
size = 500
ax.scatter(table[f"spore_density_num_{size}"],table['speed+'])
ax.scatter(table[f"spore_density_num_{size}"],table['speed-'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax = plt.subplots()
ax.scatter(table['tot_num_spore'],table[f"speed+"])
group = table.groupby('tot_num_spore')['speed+'].median()
ax.plot(group.index,group)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
column = table['speed+']+table['speed-']
column = column.replace(np.inf,0)
column = column.replace(-np.inf,0)

np.mean(column),np.std(column)/np.sqrt(len(column))
# Out:
# (-0.23610059807692282, 0.6568741213903043)

# %%
fig,ax = plt.subplots()
select = table.loc[table['speed+']<=25]
select = select.loc[select['speed-']>=-25]
ax.scatter(select['speed-'],select['speed+'])
select['speed-group'] = select['speed-'].replace(-np.inf,0).astype(int)
groups = select.groupby('speed-group')['speed+'].median()
ax.plot(groups.index,groups,color='black')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
table
# Out:
#     Unnamed: 0  kymo_id  video_id  posx  posy   speed+    speed-  \
# 0            0        1         1  4851   566   7.0437  -14.6430
# 1            1        2         1  4851   566  24.0480  -46.8660
# 2            2        3         1  4851   566  11.5420 -113.8200
# 3            3        4         2  4750   872  17.2230  -46.4940
# 4            4        5         2  4750   872  19.5500  -19.7400
# ..         ...      ...       ...   ...   ...      ...       ...
# 25          25       27        16  3315  4000   8.2526   -7.3031
# 26          26       28        16  3315  4000   9.4028   -5.4898
# 27          27       29        17  3782  3779   8.2378  -12.0370
# 28          28       30        18  4388  3504   6.6123   -8.3259
# 29          29       31        19  5088  3302   3.1267   -1.5559
#
#     spore_density_2000  spore_density_1000  spore_density_500  \
# 0             0.003094            0.001728                0.0
# 1             0.003094            0.001728                0.0
# 2             0.003094            0.001728                0.0
# 3             0.002210            0.000000                0.0
# 4             0.002210            0.000000                0.0
# ..                 ...                 ...                ...
# 25            0.001710            0.000000                0.0
# 26            0.001710            0.000000                0.0
# 27            0.002396            0.000000                0.0
# 28            0.000686            0.000000                0.0
# 29            0.000000            0.000000                0.0
#
#     spore_density_num_2000  spore_density_num_1000  spore_density_num_500  \
# 0                        2                       1                      0
# 1                        2                       1                      0
# 2                        2                       1                      0
# 3                        3                       0                      0
# 4                        3                       0                      0
# ..                     ...                     ...                    ...
# 25                       2                       0                      0
# 26                       2                       0                      0
# 27                       3                       0                      0
# 28                       1                       0                      0
# 29                       0                       0                      0
#
#     time_since_crossing  tot_num_spore  speed-group  group_density
# 0                   NaN            380          -14              2
# 1                   NaN            380          -46              2
# 2                   NaN            380         -113              2
# 3                   NaN            380          -46              3
# 4                   NaN            380          -19              3
# ..                  ...            ...          ...            ...
# 25                  NaN             72           -7              2
# 26                  NaN             72           -5              2
# 27                  NaN             72          -12              3
# 28                  NaN             72           -8              1
# 29                  NaN             72           -1              0
#
# [260 rows x 17 columns]

# %%
# grouping_window_mult = 13
# table['group_density'] = (table[f"spore_density_{size}"]*grouping_window_mult).astype(int)
size = 1000
table['group_density'] = table[f"spore_density_num_{size}"]
speedp = table.groupby('group_density')['speed+'].median()
speedm = table.groupby('group_density')['speed-'].median()
speedp_error = table.groupby('group_density')['speed+'].std()
speedp_count = table.groupby('group_density')['speed+'].count()

speedm = table.groupby('group_density')['speed-'].median()
speedm_error = table.groupby('group_density')['speed-'].std()
speedm_count = table.groupby('group_density')['speed-'].count()

# space_pixel_size = 1.725
speedp.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64', name='group_density')

# %%
fig,ax = plt.subplots()
# ax.scatter(table["group_density"]/grouping_window_mult/space_pixel_size**2,table['speed-'])
ax.plot(speedp.index,speedp)
ax.errorbar(speedp.index,speedp,speedp_error/np.sqrt(speedp_count))
ax.plot(speedp.index,speedm)
ax.errorbar(speedp.index,speedm,speedm_error/np.sqrt(speedm_count))
ax.set_xlabel('spore biovolume density ($\mu m^{3}.\mu m^{-2}$)')
ax.set_ylabel('maximum speeds ($\mu m.s^{-1}$)')
# Out:
# Text(0, 0.5, 'maximum speeds ($\\mu m.s^{-1}$)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
table['speed']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# Name: speed, Length: 260, dtype: float64

# %%
size = 500
table['group_density'] = table[f"spore_density_num_{size}"]
table['abs_speed-'] = -table['speed-']
table['speed'] = table[['speed+','abs_speed-']].max(1)

speed = table.groupby('group_density')['speed'].median()
speed_error = table.groupby('group_density')['speed'].std()
speed_count = table.groupby('group_density')['speed'].count()
fig,ax = plt.subplots()
ax.scatter(table[f"spore_density_num_{size}"],table[f"speed"],alpha = 0.1)

# ax.scatter(table["group_density"]/grouping_window_mult/space_pixel_size**2,table['speed-'])
ax.plot(speed.index,speed)
ax.errorbar(speed.index,speed,speed_error/np.sqrt(speed_count))
# ax.plot(speedp.index,speedm)
# ax.errorbar(speedp.index,speedm,speedm_error/np.sqrt(speedm_count))
ax.set_xlabel(f'number of spores at less than {size}$\mu m$')
ax.set_ylabel('maximum speeds ($\mu m.s^{-1}$)')
ax.set_yscale('log')
ax.set_ylim(1,100)
# Out:
# (1, 100)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
