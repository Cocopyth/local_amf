# %%
# %load_ext autoreload
# %autoreload 2
import os
import matplotlib.pyplot as plt
import os
import pandas as pd
from amftrack.util.sys import get_analysis_folders,get_time_plate_info_from_analysis,get_time_hypha_info_from_analysis,get_global_hypha_info_from_analysis 
import numpy as np
import imageio
import os
import cv2
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit
from amftrack.pipeline.final_analysis.density_wave import get_wave_fit, S, dS, wave, dwave,plot_single_plate
import matplotlib.patches as mpatches
import statsmodels.api as sm
from amftrack.pipeline.final_analysis.hypha_speed_analysis import *
import scipy
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import scipy.io as sio
import matplotlib as mpl
from matplotlib.path import Path
from matplotlib.patches import PathPatch
from matplotlib.legend_handler import HandlerTuple
import seaborn as sns
from scipy.integrate import odeint
import scienceplots
import logging
logging.getLogger().setLevel(logging.WARNING)
# %matplotlib widget
plt.style.use('presentation.mplstyle')
# plt.style.use('science')
plates = ['94_20201123']
plate_select = [94]
# plt.rcParams['font.family'] = 'Helvetica'  # Set font family
# Out:
# c:\users\coren\documents\phd\code\amftrack\amftrack\util\dbx.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
all_analysis_folders = get_analysis_folders()
analysis_folders = all_analysis_folders.loc[all_analysis_folders['unique_id'].isin(plates)]

folders,time_plate_info = get_time_plate_info_from_analysis(analysis_folders,use_saved=False)
time_plate_info["time_since_begin"] = time_plate_info["time_since_begin"]/pd.Timedelta(hours = 1)
time_plate_info = time_plate_info.sort_values('time_since_begin')
time_plate_info['time_delta'] = -time_plate_info['time_since_begin'].diff(-1)
for index in range(20):
    time_plate_info[f"rhon-{index}"] = time_plate_info[f"ring_active_tips_density_incr-100_index-{index}"]*time_plate_info[f"ring_density_incr-100_index-{index}"]
#     time_plate_info[f"ring_branch_density_incr-100_index-{index}"] = time_plate_info[f"ring_branch_density_incr-100_index-{index}"]/time_plate_info['time_delta'] 
#     time_plate_info[f"ring_anas_density_incr-100_index-{index}"] = time_plate_info[f"ring_anas_density_incr-100_index-{index}"]/time_plate_info['time_delta'] 

folders, time_hypha_info = get_time_hypha_info_from_analysis(analysis_folders)

# %%
path_figure = r"C:\Users\coren\AMOLF-SHIMIZU Dropbox\HFSP_symbiotic-networks\Article_TravellingWave\Figure3\Figures3Figure"
width = 1.6
height = 1

# %%
def find_t0(index,table):
    column = f"ring_density_incr-100_index-{index}"
    column2 = f"ring_active_tips_density_incr-100_index-{index}"

    start = np.min(
        table.loc[table[column] >= 400]["time_since_begin"]
    )
    table[f"time_since_begin_{index}"] = (
        table["time_since_begin"] - start
    )

    area = np.sqrt(table["area_sep_comp"][0] + 100 * index)
    selection_fit = table
    xis,yis = selection_fit[f"time_since_begin_{index}"],selection_fit[column]

    selection_fit = table

    popt0, pcov = curve_fit(
        S,
        xis,
        yis,
        bounds=([0, 0, -np.inf], 3 * [np.inf]),
        p0=[1, 1, 0],
    )
    lamb, C, t0 = list(popt0)
    return(t0)

# %%
plt.close('all')
plate = 94

fig, ax = plt.subplots()
tstot = []
ystot = []
ys2tot = []
ys3tot = []
ys4tot = []


ax2 = ax.twinx()

table = time_plate_info.loc[time_plate_info["Plate"]==plate].copy()
ts = []
ys = []
ys2 = []
for index in range(15):
    column = f"ring_anas_density_incr-100_index-{index}"
#         column = f"ring_active_tips_density_incr-100_index-{index}"

    column2 = f"ring_active_tips_density_incr-100_index-{index}"
    column3 = f"ring_density_incr-100_index-{index}"
    column4 = f"rhon-{index}"
    
    start1 = np.min(table.loc[table[f"ring_density_incr-100_index-{index}"]>=400]['time_since_begin'])
    start = find_t0(index,table)+start1
    if not np.isnan(start):
        table[f'time_since_begin_{index}']=table['time_since_begin']-start
#             ax.plot(table[f'time_since_begin_{index}'],table[column],alpha=0.2,color='blue')
#             ax2.plot(table[f'time_since_begin_{index}'],table[column2],alpha=0.2,color='red')

        x = f'time_since_begin_{index}'
        deb = np.min(table[x])
        end = np.max(table[x])
        time = np.linspace(deb,end,1000)
        tstot +=list(time)
        f = interp1d(table[x], table[column])
        ystot += list(f(time))
        f = interp1d(table[x], table[column2])
        ys2tot+=list(f(time))
        f = interp1d(table[x], table[column3])
        ys3tot+=list(f(time))
        f = interp1d(table[x], table[column4])
        ys4tot+=list(f(time))
df = pd.DataFrame((np.array((tstot,ystot,ys2tot,ys3tot,ys4tot))).transpose(),columns=('ts','ys','ys2','ys3','ys4'))
factor = 1
df['ts_round'] = np.floor(df['ts']/factor)*factor
meancurve = df.groupby('ts_round')['ys'].mean()
ax.plot(meancurve.index,meancurve,linewidth = 5)
meancurve3 = df.groupby('ts_round')['ys2'].mean()
meancurve4 = df.groupby('ts_round')['ys3'].mean()
meancurve4 = df.groupby('ts_round')['ys4'].mean()


ax2.plot(meancurve3.index,meancurve3*meancurve4,linewidth = 5,color='red')
# ax2.set_color('red')
ax.set_xlim((-30,30))
ax.set_ylim((0,0.0035))
ax2.set_ylim((0,190))

ax.set_ylabel('anastomosis density ($mm^{-2}.h^{-1}$)')
ax.set_xlabel('shifted time ($h$)')
ax2.set_ylabel(r'$\rho n$ ($\mu m. mm^{-4}$)')
ax.tick_params(axis='y', colors='blue')
ax2.tick_params(axis='y', colors='red')
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plot_shade(xcolumn,ycolumn,color,ax):
    meancurve = df.groupby(xcolumn)[ycolumn].mean()
    stdcurve = df.groupby(xcolumn)[ycolumn].std()
    countcurve = df.groupby(xcolumn)[ycolumn].count()
    err = 2*stdcurve/np.sqrt(countcurve)
    ax.plot(meancurve.index,meancurve,color=color,linewidth = 1)
    ax.fill_between(meancurve.index, meancurve-err, meancurve+err,color=color,alpha = 0.4)
    return(meancurve)

# %%
plate = 94

plt.close('all')
table = time_plate_info.loc[time_plate_info["Plate"]==plate].copy()
ts = []

ys = []
ys2 = []
ys3 = []
ys4 = []




# ax3.plot(meancurve3.index,meancurve3*meancurve4,linewidth = 5,color='green')


for index in range(20):
    column = f"ring_anas_density_incr-100_index-{index}"
    column2 = f"ring_active_tips_density_incr-100_index-{index}"
    column3 = f"ring_branch_density_incr-100_index-{index}"
    column4 = f"rhon-{index}"
    
    start1 = np.min(table.loc[table[f"ring_density_incr-100_index-{index}"]>=400]['time_since_begin'])
    start = find_t0(index,table)+start1
    if not np.isnan(start):
        table[f'time_since_begin_{index}']=table['time_since_begin']-start
        # ax.plot(table[f'time_since_begin_{index}'],table[column],alpha=0.2,color='blue')
        # ax2.plot(table[f'time_since_begin_{index}'],table[column2],alpha=0.2,color='red')

        ts +=table[f'time_since_begin_{index}'].to_list()
        ys += table[column].astype(float).to_list()
        ys2+=table[column2].astype(float).to_list()
        ys3+=table[column3].astype(float).to_list()
        ys4+=table[column4].astype(float).to_list()
        
df = pd.DataFrame((np.array((ts,ys,ys2,ys3,ys4))).transpose(),columns=('ts','ys','ys2','ys3','ys4'))
factor = 4
df['ts_round'] = (df['ts']/factor).astype(int)*factor+factor/2
xcolumn = 'ts_round'
# meancurve = df.groupby('ts_round')['ys'].mean()
# ax.plot(meancurve.index,meancurve,color="blue",linewidth = 5)



f, ax = plt.subplots(1, 1, sharex=True,figsize=(width,height))

# ax4.set_ylabel(r'branching density ($mm^{-2}.h^{-1}$)')
# plt.tight_layout()

ax3 = ax.twinx()
anas = plot_shade(xcolumn,'ys','purple',ax)

rhon = plot_shade(xcolumn,'ys4','green',ax3)
ax.set_ylabel('a ($mm^{-2}.hour^{-1}$)',)

ax.set_xlabel('shifted time, $t-t_n$ ($hour$)')
ax3.set_ylabel(r'$\rho n$ ($mm^{-3}$)')
ax.set_ylim((0,0.0025))
ax3.set_ylim((0,100))

ax.tick_params(axis='y', colors='purple')
ax3.tick_params(axis='y', colors='green')
ax.set_xlim((-30,30))
ax.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
plt.savefig(os.path.join(path_figure,'Figure3D2.pdf'), bbox_inches='tight')

f, ax4 = plt.subplots(1, 1, sharex=True,figsize=(width,height))
ax2 = ax4.twinx()

n = plot_shade(xcolumn,'ys2','red',ax2)
branch = plot_shade(xcolumn,'ys3','orange',ax4)
ax2.set_ylabel('n ($mm^{-2}$)')
ax4.set_ylabel(r'b ($mm^{-2}.hour^{-1}$)')
ax2.tick_params(axis='y', colors='red')
ax4.tick_params(axis='y', colors='orange')
ax4.set_ylim((0,0.040))

ax2.set_xlim((-30,30))
ax2.set_ylim((0,0.140))
ax2.set_xticklabels([])
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax4.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# plt.savefig(os.path.join(path_figure,'Figure3D.png'))
# plt.savefig(os.path.join(path_figure,'Figure3D.EPS'))
plt.savefig(os.path.join(path_figure,'Figure3D1.pdf'), bbox_inches='tight',transparent=True)

# %%
plate = 94

plt.close('all')
table = time_plate_info.loc[time_plate_info["Plate"]==plate].copy()
ts = []

ys = []
ys2 = []
ys3 = []
ys4 = []


f, (ax4, ax) = plt.subplots(2, 1, sharex=True,figsize=(7,6))
ax3 = ax.twinx()
ax2 = ax4.twinx()


# ax3.plot(meancurve3.index,meancurve3*meancurve4,linewidth = 5,color='green')


for index in range(20):
    column = f"ring_active_tips_density_incr-100_index-{index}"
    column2 = f"ring_active_tips_density_incr-100_index-{index}"
    column3 = f"ring_branch_density_incr-100_index-{index}"
    column4 = f"ring_stop_density_incr-100_index-{index}"
    
    start1 = np.min(table.loc[table[f"ring_density_incr-100_index-{index}"]>=400]['time_since_begin'])
    start = find_t0(index,table)+start1
    if not np.isnan(start):
        table[f'time_since_begin_{index}']=table['time_since_begin']-start
        # ax.plot(table[f'time_since_begin_{index}'],table[column],alpha=0.2,color='blue')
        # ax2.plot(table[f'time_since_begin_{index}'],table[column2],alpha=0.2,color='red')

        ts +=table[f'time_since_begin_{index}'].to_list()
        ys += table[column].astype(float).to_list()
        ys2+=table[column2].astype(float).to_list()
        ys3+=table[column3].astype(float).to_list()
        ys4+=table[column4].astype(float).to_list()
        
df = pd.DataFrame((np.array((ts,ys,ys2,ys3,ys4))).transpose(),columns=('ts','ys','ys2','ys3','ys4'))
factor = 4
df['ts_round'] = (df['ts']/factor).astype(int)*factor+factor/2
xcolumn = 'ts_round'
# meancurve = df.groupby('ts_round')['ys'].mean()
# ax.plot(meancurve.index,meancurve,color="blue",linewidth = 5)
anas = plot_shade(xcolumn,'ys','purple',ax)
n = plot_shade(xcolumn,'ys2','red',ax2)
branch = plot_shade(xcolumn,'ys3','orange',ax4)
rhon = plot_shade(xcolumn,'ys4','green',ax3)


# meancurve2 = df.groupby('ts_round')['ys2'].mean()
# ax2.plot(meancurve2.index,meancurve2,color="red",linewidth = 5)
# meancurve5 = df.groupby('ts_round')['ys3'].mean()
# ax4.plot(meancurve5.index,meancurve5,color="purple",linewidth = 5)
# ax2.set_color('red')
ax2.set_xlim((-30,30))
ax2.set_ylim((0,0.140))
ax.set_ylim((0,0.140))

ax3.set_ylim((0,0.14))
ax4.set_ylim((0,0.040))


# ax3.spines['right'].set_position(('outward', 100))
# ax4.spines['right'].set_position(('outward', 200))

# ax.set_ylabel('anastomosis density ($mm^{-2}.h^{-1}$)')
ax.set_ylabel('a ($mm^{-2}.h^{-1}$)')

ax.set_xlabel('shifted time ($h$)')
ax2.set_ylabel('n ($mm^{-2}$)')
ax3.set_ylabel(r'$\rho n$ ($mm^{-3}$)')
# ax4.set_ylabel(r'branching density ($mm^{-2}.h^{-1}$)')
ax4.set_ylabel(r'b ($mm^{-2}.h^{-1}$)')



ax.tick_params(axis='y', colors='purple')
ax2.tick_params(axis='y', colors='red')
ax3.tick_params(axis='y', colors='green')
ax4.tick_params(axis='y', colors='orange')


plt.tight_layout()
plt.savefig(os.path.join(path_figure,'wave_timing.png'))
plt.savefig(os.path.join(path_figure,'wave_timing.EPS'))
# Out:
# 2023-04-07 14:00:02,602-[WARNING]- matplotlib.backends.backend_ps:296 -> The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
low,up = -10,10
sanas = anas.loc[(anas.index>=low) & (anas.index<=up)]
srhon = rhon.loc[(rhon.index>=low) & (rhon.index<=up)]
low,up = -20,-10
sn = n.loc[(n.index>=low) & (n.index<=up)]
sbranch = branch.loc[(branch.index>=low) & (branch.index<=up)]
np.mean(sanas/srhon),np.mean(sbranch/sn)
# np.mean(sbranch/sn)

# %%
sn = n.loc[n>=0.05]
sbranch = branch.loc[branch>=0.02]
1/(np.sum(sbranch)/np.sum(sn))

# %%
list_hyph = [0,6,118,58,85,1]
data = pd.DataFrame()
for hyph_label in list_hyph:
    t_real = np.load(f"branches/ts_{hyph_label}_auto.npy")
    distances = np.load(f"branches/distances_{hyph_label}_auto.npy")
    # fig,ax = plt.subplots()
    # ax.plot(distances)
    times = np.load(f"branches/times_{hyph_label}_auto.npy")
    hyph = [hyph_label for time in times]
    data = pd.concat((data,pd.DataFrame((np.array((times,distances,hyph))).transpose(),columns=('time','distance','hyph'))))

# %%
fig,ax = plt.subplots(figsize=(width,height))
# sns.histplot(all_times,ax=ax)
# ax.hist(all_times,15)
# sns.set(rc={'figure.figsize':(1.5,1.5)})
g  = sns.histplot(data=data,x ='time', color="grey",ax=ax)
ax.set_xlabel("$\Delta t_{branching}$ ($hour$)")
ax.xaxis.labelpad = 1
ax.yaxis.labelpad = 1

# plt.tight_layout()

# plt.savefig(os.path.join(path_figure,'Figure3C.png'))
plt.savefig(os.path.join(path_figure,'Figure3C.pdf'), bbox_inches='tight',transparent=True)
# plt.savefig(os.path.join(path_figure,'Figure3C.svg'))

# %%
np.mean(data['time'])
# Out:
# 3.0718505816114736

# %%
plate_id = '94_20201123'
plate_id_int = int(plate_id)
data,dy,select_movements = get_average_time_data(plate_id_int,time_hypha_info,2)
hyphae_hull = get_hyphae_hull(plate_id,analysis_folders)

# %%
timesteps = []
hypha_hulls = []
for timestep,line in enumerate(hyphae_hull):
    timesteps += [timestep for hyph in line]
    hypha_hulls += [hyph for hyph in line]
data_front = pd.DataFrame((np.array((timesteps,hypha_hulls))).transpose(),columns=('timestep','label'))
data_front['timestep_label'] = data_front['timestep'].astype(str)+data_front['label'].astype(str)

# %%
select_movements['group_time'] = select_movements['timestep']//10
select_movements['timestep_label'] = select_movements['timestep'].astype(str)+select_movements['end'].astype(str)

select_movements['is_hull_pusher'] = select_movements["timestep_label"].isin(data_front['timestep_label'])
select = select_movements.loc[select_movements['timestep']<100]

# %%
np.mean(select['speed'])
# Out:
# 227.00080278718002

# %%
fig,ax = plt.subplots(figsize=(width,height))

sns.set_palette(['pink', 'cyan', 'blue'])
g  = sns.histplot(data=select,x ='speed', kde=True,color="grey",hue = "is_hull_pusher",common_norm=False,ax=ax)
ax.legend().remove()
ax.set_xlabel("growth speed ($\mu m.hour^{-1}$)")
ax.set_yscale("log")
ax.set_ylim(1,300)
ax.xaxis.labelpad = 1
ax.yaxis.labelpad = 1
# plt.tight_layout()


# plt.savefig(os.path.join(path_figure,'Figure3B.png'))
plt.savefig(os.path.join(path_figure,'Figure3B.pdf'), bbox_inches='tight',transparent=True)
# plt.savefig(os.path.join(path_figure,'Figure3B.svg'))
# Out:
# 2023-04-16 10:37:24,327-[WARNING]- matplotlib.legend:1236 -> No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2023-04-16 10:37:25,468-[WARNING]- fontTools.subset:2983 -> meta NOT subset; don't know how to subset; dropped
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
f, (ax, ax2) = plt.subplots(2, 1, sharex=True,figsize=(1.2,1.5))

c =2.5
def model(y,t):
    dydt = [(1/(1-c))*y[0]*(1-y[1]),-1/c * y[0]]
    return dydt
# initial condition
y0 = [0.0001,0.0001]

# time points
ta = np.linspace(0,20,1000)

# solve ODE
ya = odeint(model,y0,ta)

# plot results
tb = np.linspace(0,-40,1000)

# solve ODE
yb = odeint(model,y0,tb)

ind = 0
# plot results
ax2.plot(np.concatenate((np.flip(tb),ta)),np.concatenate((np.flip(yb[:,ind]),ya[:,ind])),label=f'c = {int(c*10)/10}',color = 'red',linewidth = 3)
ind = 1
ax.plot(np.concatenate((np.flip(tb),ta)),np.concatenate((np.flip(yb[:,ind]),ya[:,ind])),label=f'c = {int(c*10)/10}',color="blue",linewidth = 3)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.set_xlim(-40,0)
# Set the tick parameters
ax.tick_params(axis='both', which='both', direction='out', top=False, right=False,left=False,bottom=False)
ax2.tick_params(axis='both', which='both', direction='out', top=False, right=False,left=False,bottom=False)
# ax.set_xticklabels([])
ax.set_yticklabels([])
ax2.set_xticklabels([])
ax2.set_yticklabels([])
ax2.set_xlabel('$r$')
ax2.set_ylabel('$n$',color='red')
ax.set_ylabel(r'$\rho$',color='blue')
plt.tight_layout()
plt.savefig(os.path.join(path_figure,'model.png'))
plt.savefig(os.path.join(path_figure,'model.EPS'))
plt.savefig(os.path.join(path_figure,'model.pdf'))
# Out:
# 2023-04-12 11:50:32,120-[INFO]- fontTools.subset:2815 -> maxp pruned
# 2023-04-12 11:50:32,145-[INFO]- fontTools.subset:2815 -> cmap pruned
# 2023-04-12 11:50:32,147-[INFO]- fontTools.subset:2799 -> kern dropped
# 2023-04-12 11:50:32,149-[INFO]- fontTools.subset:2815 -> post pruned
# 2023-04-12 11:50:32,150-[INFO]- fontTools.subset:2799 -> FFTM dropped
# 2023-04-12 11:50:32,156-[INFO]- fontTools.subset:2815 -> GPOS pruned
# 2023-04-12 11:50:32,826-[INFO]- fontTools.subset:2815 -> GSUB pruned
# 2023-04-12 11:50:32,829-[INFO]- fontTools.subset:2815 -> name pruned
# 2023-04-12 11:50:32,842-[INFO]- fontTools.subset:2815 -> glyf pruned
# 2023-04-12 11:50:32,844-[INFO]- fontTools.subset:2855 -> Added gid0 to subset
# 2023-04-12 11:50:32,846-[INFO]- fontTools.subset:2863 -> Added first four glyphs to subset
# 2023-04-12 11:50:32,847-[INFO]- fontTools.subset:2867 -> Closing glyph list over 'GSUB': 7 glyphs before
# ...

# %%
os.path.join(path_figure,'model.png')
# Out:
# 'C:\\Users\\coren\\AMOLF-SHIMIZU Dropbox\\HFSP_symbiotic-networks\\Article_TravellingWave\\Figure2\\versionsFromCoco\\model.png'

# %%
plates = [
    "26_20210104",
    "52_20220707",
    "56_20220701",
    "59_20201126",
    "69_20201119",
    "76_20210108",
    "81_20220704",
    "84_20220621",
    "94_20201123",
    "102_20201226",
    "152_20201224",
    "792_20210915",
    "799_20211001"
    
]
analysis_folders = all_analysis_folders.loc[all_analysis_folders['unique_id'].isin(plates)]
folders,time_plate_info = get_time_plate_info_from_analysis(analysis_folders,use_saved=False)

# %%
time_plate_info['anastomosis'] = time_plate_info['num_edges_study']-time_plate_info['num_nodes_study']+2
time_plate_info['anastomosis_density']=time_plate_info['anastomosis']/time_plate_info['tot_length_study']
time_plate_info['branching'] = time_plate_info['anastomosis']+time_plate_info['num_tips_study']-time_plate_info['num_tips_BAS_study']
time_plate_info['branching_density']=time_plate_info['branching']/time_plate_info['tot_length_study']
time_plate_info['day'] = (time_plate_info["time_since_begin_h"]/24).astype(int)
time_plate_info['4h'] = (time_plate_info["time_since_begin_h"]/4).astype(int)
# Out:
# C:\Users\coren\AppData\Local\Temp\ipykernel_11572\2675876120.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   time_plate_info['anastomosis'] = time_plate_info['num_edges_study']-time_plate_info['num_nodes_study']+2
# C:\Users\coren\AppData\Local\Temp\ipykernel_11572\2675876120.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   time_plate_info['anastomosis_density']=time_plate_info['anastomosis']/time_plate_info['tot_length_study']
# ...

# %%
plt.close("all")
# fig,ax = plt.subplots(figsize=(6,2))
fig,ax = plt.subplots()

y = "anastomosis"

for unique_id in time_plate_info['unique_id'].unique():
    select = time_plate_info.loc[time_plate_info['time_since_begin_h']<100]
    select = select.loc[select['unique_id']==unique_id]
    select = select.loc[select[y]>0]
    select = select.sort_values('time_since_begin_h')
    if len(select)>0:
        ax.scatter(select["time_since_begin_h"],select[y]*1000,label=unique_id,alpha = 0.2)


table_group = time_plate_info.set_index('unique_id').copy()
table_group = table_group.loc[table_group[y]<1000]
data = table_group.groupby('4h')[y].mean()
data = data.loc[data.index<25]
data*=1000
datastd = table_group.groupby('4h')[y].std()
datastd = datastd.loc[datastd.index<25]
datastd*=1000

datacount = table_group.groupby('4h')[y].count()
datacount = datacount.loc[datacount.index<25]
err = 2*datastd/np.sqrt(datacount)

ax.plot(data.index*4,data,color="black")
ax.fill_between(data.index*4, data-err, data+err,color="grey",alpha = 0.6)

ax.set_yscale('log')
# ax.legend()
ax.set_ylim(1e4,2e6)
ax.set_xlabel('time (h)')
ax.set_ylabel('Number of anastomosis')
plt.tight_layout()
plt.savefig(os.path.join(path_figure,'anas_time.png'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
time_plate_info.columns
# Out:
# Index(['num_trunks', 'area', 'area_sep_comp', 'num_tips', 'num_nodes',
#        'area_study', 'num_tips_study', 'num_nodes_study', 'num_edges_study',
#        'tot_length',
#        ...
#        'ring_active_tips_density_incr-2_index-16',
#        'ring_active_tips_density_incr-2_index-17',
#        'ring_active_tips_density_incr-2_index-18',
#        'ring_active_tips_density_incr-2_index-19', 'anastomosis',
#        'anastomosis_density', 'branching', 'branching_density', 'day', '4h'],
#       dtype='object', length=198)

# %%
plt.close("all")
# fig,ax = plt.subplots(figsize=(6,2))
fig,ax = plt.subplots()

y = "tot_length_study"

for unique_id in time_plate_info['unique_id'].unique():
    select = time_plate_info.loc[time_plate_info['time_since_begin_h']<100]
    select = select.loc[select['unique_id']==unique_id]
    select = select.loc[select[y]>0]
    select = select.sort_values('time_since_begin_h')
    if len(select)>0:
        ax.scatter(select["time_since_begin_h"],select[y]/1000,label=unique_id,alpha = 0.2)


table_group = time_plate_info.set_index('unique_id').copy()
# table_group = table_group.loc[table_group[y]<1000]
data = table_group.groupby('4h')[y].mean()
data = data.loc[data.index<25]
data/=1000
datastd = table_group.groupby('4h')[y].std()
datastd = datastd.loc[datastd.index<25]
datastd/=1000

datacount = table_group.groupby('4h')[y].count()
datacount = datacount.loc[datacount.index<25]
err = 2*datastd/np.sqrt(datacount)

ax.plot(data.index*4,data,color="black")
ax.fill_between(data.index*4, data-err, data+err,color="grey",alpha = 0.6)

ax.set_yscale('log')
# ax.legend()
# ax.set_ylim(1e4,2e6)
ax.set_xlabel('time (h)')
ax.set_ylabel('L (mm)')
plt.tight_layout()
plt.savefig(os.path.join(path_figure,'L_time.png'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
fig,ax = plt.subplots(figsize=(8,4))
# fig,ax = plt.subplots()

y = "anastomosis_density"

for unique_id in time_plate_info['unique_id'].unique():
    select = time_plate_info.loc[time_plate_info['time_since_begin_h']<100]
    select = select.loc[select['unique_id']==unique_id]
    select = select.loc[select[y]>0]
    select = select.sort_values('time_since_begin_h')
    if len(select)>0:
        ax.scatter(select["time_since_begin_h"],select[y]*1000,label=unique_id,alpha = 0.2)


table_group = time_plate_info.set_index('unique_id').copy()
table_group = table_group.loc[table_group[y]<1000]
data = table_group.groupby('4h')[y].mean()
data = data.loc[data.index<25]
data*=1000
datastd = table_group.groupby('4h')[y].std()
datastd = datastd.loc[datastd.index<25]
datastd*=1000

datacount = table_group.groupby('4h')[y].count()
datacount = datacount.loc[datacount.index<25]
err = 2*datastd/np.sqrt(datacount)

ax.plot(data.index*4,data,color="black")
ax.fill_between(data.index*4, data-err, data+err,color="grey",alpha = 0.6)

# ax.set_yscale('log')
# ax.legend()
ax.set_ylim(0,1.25)
ax.set_xlabel('time (h)')
ax.set_ylabel('anastomosis density ($mm^{-1}$)')
# plt.savefig(os.path.join(path_figure,'Figure2.5A.EPS'))
plt.tight_layout()
plt.savefig(os.path.join(path_figure,'anas_dens_time.png'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
fig,ax = plt.subplots(figsize=(8,4))
# fig,ax = plt.subplots()

y = "branching_density"

for unique_id in time_plate_info['unique_id'].unique():
    select = time_plate_info.loc[time_plate_info['time_since_begin_h']<100]
    select = select.loc[select['unique_id']==unique_id]
    select = select.loc[select[y]>0]
    select = select.sort_values('time_since_begin_h')
    if len(select)>0:
        ax.scatter(select["time_since_begin_h"],select[y]*1000,label=unique_id,alpha = 0.2)


table_group = time_plate_info.set_index('unique_id').copy()
table_group = table_group.loc[table_group[y]<1000]
data = table_group.groupby('4h')[y].mean()
data = data.loc[data.index<25]
data*=1000
datastd = table_group.groupby('4h')[y].std()
datastd = datastd.loc[datastd.index<25]
datastd*=1000

datacount = table_group.groupby('4h')[y].count()
datacount = datacount.loc[datacount.index<25]
err = 2*datastd/np.sqrt(datacount)

ax.plot(data.index*4,data,color="black")
ax.fill_between(data.index*4, data-err, data+err,color="grey",alpha = 0.6)

# ax.set_yscale('log')
# ax.legend()
ax.set_ylim(0,1.25)
ax.set_xlabel('time (h)')
ax.set_ylabel('branch density ($mm^{-1}$)')
plt.tight_layout()
plt.savefig(os.path.join(path_figure,'branching_density.png'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
# fig,ax = plt.subplots(figsize=(6,2))
fig,ax = plt.subplots()

y = "branching_density"

table_group = time_plate_info.set_index('unique_id').copy()
table_group = table_group.loc[table_group[y]<1000]
data = table_group.groupby('4h')[y].mean()
data = data.loc[data.index<25]
data*=1000
datastd = table_group.groupby('4h')[y].std()
datastd = datastd.loc[datastd.index<25]
datastd*=1000

datacount = table_group.groupby('4h')[y].count()
datacount = datacount.loc[datacount.index<25]
err = 2*datastd/np.sqrt(datacount)

ax.plot(data.index*4,data,color="black",label="branching")
ax.fill_between(data.index*4, data-err, data+err,color="grey",alpha = 0.6)

# ax.set_yscale('log')
# ax.legend()
ax.set_ylim(0,2)

y = "anastomosis_density"
# ax2 = ax.twinx()


table_group = time_plate_info.set_index('unique_id').copy()
table_group = table_group.loc[table_group[y]<1000]
data = table_group.groupby('4h')[y].mean()
data = data.loc[data.index<25]
data*=1000
datastd = table_group.groupby('4h')[y].std()
datastd = datastd.loc[datastd.index<25]
datastd*=1000

datacount = table_group.groupby('4h')[y].count()
datacount = datacount.loc[datacount.index<25]
err = 2*datastd/np.sqrt(datacount)

ax.plot(data.index*4,data,color="cyan",label="anastomosis")
ax.fill_between(data.index*4, data-err, data+err,color="cyan",alpha = 0.6)

# ax.set_yscale('log')
# ax.legend()
ax.set_ylim(0,1)
ax.set_xlabel('time (h)')
ax.set_ylabel('density ($mm^{-1}$)')
ax.legend()
plt.tight_layout()
plt.savefig(os.path.join(path_figure,'branching_anastomosis.png'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
# fig,ax = plt.subplots(figsize=(6,2))
fig,ax = plt.subplots()

y = "branching"

for unique_id in time_plate_info['unique_id'].unique():
    select = time_plate_info.loc[time_plate_info['time_since_begin_h']<100]
    select = select.loc[select['unique_id']==unique_id]
    select = select.loc[select[y]>0]
    select = select.sort_values('time_since_begin_h')
    if len(select)>0:
        ax.scatter(select["time_since_begin_h"],select[y]*1000,label=unique_id,alpha = 0.2)


table_group = time_plate_info.set_index('unique_id').copy()
table_group = table_group.loc[table_group[y]<1000]
data = table_group.groupby('4h')[y].mean()
data = data.loc[data.index<25]
data*=1000
datastd = table_group.groupby('4h')[y].std()
datastd = datastd.loc[datastd.index<25]
datastd*=1000

datacount = table_group.groupby('4h')[y].count()
datacount = datacount.loc[datacount.index<25]
err = 2*datastd/np.sqrt(datacount)

ax.plot(data.index*4,data,color="black")
ax.fill_between(data.index*4, data-err, data+err,color="grey",alpha = 0.6)

ax.set_yscale('log')
# ax.legend()
ax.set_ylim(1e4,2e6)
ax.set_xlabel('time (h)')
ax.set_ylabel('number of branches')
plt.tight_layout()
plt.savefig(os.path.join(path_figure,'branching.png'))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
