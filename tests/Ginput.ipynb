# %%
from PIL import Image
from PIL.ExifTags import TAGS
import imageio
import matplotlib.pyplot as plt

# %%
# path to the image or video
imagename = "anastomose229.tiff"
im = imageio.imread(imagename)

# %%
plt.imshow(im,cmap = 'gray')
plt.ginput(1)
# Out:
# C:\Users\coren\anaconda3\envs\cleanMsc\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# []
