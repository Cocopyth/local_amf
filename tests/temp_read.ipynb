# %%
# %matplotlib widget

import pandas as pd
table = pd.read_csv('WAVE0001.csv',skiprows = 14,delimiter=",")
# table = pd.concat((table,pd.read_csv('WAVE0001.csv',skiprows = 14,delimiter=",")))
# table = pd.read_csv('temp.csv',skiprows = 1,delimiter=";")

# %%
table
# Out:
#             Time  CH-1[C]  CH-2[C]  CH-3[C]  CH-4[C]  CH-5[C]  CH-6[C]  \
# 0       288312.0     25.5     25.1     25.0     24.8     24.9     25.0
# 1       288312.5     25.5     25.0     25.1     24.8     24.9     24.9
# 2       288313.0     25.5     25.0     25.1     24.8     24.9     24.9
# 3       288313.5     25.5     25.0     25.1     24.8     24.9     25.0
# 4       288314.0     25.5     25.0     25.1     24.8     24.9     24.9
# ...          ...      ...      ...      ...      ...      ...      ...
# 262139  419381.5     25.3     25.2     25.1     25.0     25.0     25.0
# 262140  419382.0     25.4     25.2     25.1     25.0     25.0     25.0
# 262141  419382.5     25.4     25.2     25.1     25.1     25.0     25.0
# 262142  419383.0     25.3     25.2     25.1     25.1     25.0     25.0
# 262143  419383.5     25.4     25.2     25.1     25.0     25.0     25.0
#
#         P-1[c]  P-2[c]  P-3[c]  P-4[c]  Event  Unnamed: 12
# ...

# %%
for i in range(1,7):
    table[labels[i-1]] =table[f"CH-{i}[C]"].rolling(10000).mean()

# %%
table
# Out:
#             Time  CH-1[C]  CH-2[C]  CH-3[C]  CH-4[C]  CH-5[C]  CH-6[C]  \
# 0       288312.0     25.5     25.1     25.0     24.8     24.9     25.0
# 1       288312.5     25.5     25.0     25.1     24.8     24.9     24.9
# 2       288313.0     25.5     25.0     25.1     24.8     24.9     24.9
# 3       288313.5     25.5     25.0     25.1     24.8     24.9     25.0
# 4       288314.0     25.5     25.0     25.1     24.8     24.9     24.9
# ...          ...      ...      ...      ...      ...      ...      ...
# 262139  419381.5     25.3     25.2     25.1     25.0     25.0     25.0
# 262140  419382.0     25.4     25.2     25.1     25.0     25.0     25.0
# 262141  419382.5     25.4     25.2     25.1     25.1     25.0     25.0
# 262142  419383.0     25.3     25.2     25.1     25.1     25.0     25.0
# 262143  419383.5     25.4     25.2     25.1     25.0     25.0     25.0
#
#         P-1[c]  P-2[c]  P-3[c]  P-4[c]  Event  Unnamed: 12      Time_h  \
# ...

# %%
table['Time_h']=table['Time']/3600

# %%
table.plot("Time_h",[labels[i-1] for i in range(1,7)],alpha= 0.2,ylim=(24,26))
# Out:
# <AxesSubplot:xlabel='Time_h'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
labels = ['left next to pos 3','right between pos 38 and 39','left between pos 5 and 6', 'right next to pos 37','bottom right','bottom left']

# %%
table = pd.read_csv('WAVE0002.csv',skiprows = 14,delimiter=",")
table = pd.concat((table,pd.read_csv('WAVE0001.csv',skiprows = 14,delimiter=",")))
for i in range(1,7):
    table[labels[i-1]] =table[f"CH-{i}[C]"].rolling(10000).mean()
table['Time_h']=table['Time']/3600
table.plot("Time_h",[labels[i-1] for i in range(1,7)],alpha= 0.4,ylim=(24,26))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <AxesSubplot:xlabel='Time_h'>
