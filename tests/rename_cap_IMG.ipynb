# %%
import os
path_find = r'C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE'
dirs = os.listdir(r'C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE')
dirs = [os.path.join(path_find,dire) for dire in dirs]

# %%
for dire in dirs:
    local = os.listdir(dire)
    break

# %%
for path, currentDirectory, files in os.walk(path_find):
    for file in files:
        if file=="IMG.zip":
            print(os.path.join(path, file))
# Out:
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220802_0500_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220803_0536_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220803_1358_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220804_0034_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220804_0834_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220804_1634_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220805_0034_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220805_0834_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220805_1634_Plate34\IMG.zip
# C:\Users\coren\AMOLF-SHIMIZU Dropbox\DATA\PRINCE\122_20220711\20220806_0034_Plate34\IMG.zip
# ...

# %%
for path, currentDirectory, files in os.walk(path_find):
    for file in files:
        if file=="IMG.zip":
            os.rename(os.path.join(path, file),os.path.join(path, 'Img.zip'))
